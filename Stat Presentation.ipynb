# %% [markdown]
# # Stats Presentations

# %% [markdown]
# This iPython notebook is in accompanment to a paper by Colin E. Seale

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pymc
from IPython.core.pylabtools import figsize
import scipy.stats as stats
from numpy import array, concatenate, ones
import pymc as pm
from scipy.stats import shapiro

# %%
figsize(19.5, 5.5)
data_df = pd.read_csv('data/txtdata_y2k.csv')
count_data = np.loadtxt("data/txtdata.csv")
data_df = np.round(data_df, 0)
count_data = np.round(count_data, 0)
n_count_data = len(count_data)
plt.bar(np.arange(n_count_data), count_data, color="#348ABD")
plt.xlabel("Time (months)")
plt.ylabel("number of people killed in terror attcks")
plt.title("Has terrorist activity changed over time?")
plt.xlim(0, n_count_data);
data_df.nkill.hist(bins = 20)

# %% [markdown]
# ### A frequentist model for the switchpoint

# %% [markdown]
# We begin with a regression model where the change point is a dummy variable that represents the data at time t. We call this variable $\tau^*$, it represents the hypothesised change point. An indicator varible that sets all observations with a t less than $\tau^*$ to zero. So our model looks like this,
# $$\hat{y} = \beta_0 + \beta_1{I(\tau^*, 0
# )} $$

# %%
def ols_helper(hyp_tau, data_df):
    temp_dummy = np.array(data_df.t >= hyp_tau, dtype = bool)
    temp_data = pd.DataFrame([data_df.nkill, temp_dummy.astype(int)]).T
    temp_data.columns = ['nkill','tau_']
    temp_ols = ols(formula='nkill ~ C(tau_)', data = temp_data)
    return temp_ols.fit()

# %%
rsq_dict = {'rsq': []}
from statsmodels.formula.api import ols
for i in range(0, n_count_data):
    temp_model = ols_helper(i, data_df)
    rsq_dict['rsq'].append(temp_model.rsquared)
rsq_df = pd.DataFrame(rsq_dict)
data_df = pd.concat([data_df, rsq_df], axis = 1)

# %%
data_df.rsq.plot(title = '$R^2$ Plot for OLS Model 1')
plt.ylabel('$R^2$')
plt.xlabel('$t$  (months)')
max_rsq = data_df[data_df.rsq == float(data_df.rsq.values.max())]
tau_full_ols = max_rsq.t
max_rsq
# Out:
#      iyear  imonth  nkill    t       rsq
# 144   2012       1   1689  144  0.438322

# %% [markdown]
# The maximum $R^2$ is at $t$ = 144. So the dummy varible $\tau_*$ is eqaul to 1 for all values for greater or equal to $t$ = 144 and 0 for those counts less than $t$ = 144, so that the indicator function looks like this,

# %% [markdown]
# $$
# \tau_* =
# \begin{cases}
# 0  & \text{if } t \lt 144 \cr
# 1 & \text{if } t \ge 144
# \end{cases}
# $$

# %%
max_full_ols = ols_helper(float(tau_full_ols), data_df)
max_full_ols
infl = max_full_ols.get_influence()
print max_full_ols.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  nkill   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.435
# Method:                 Least Squares   F-statistic:                     129.5
# Date:                Sun, 19 Apr 2015   Prob (F-statistic):           1.49e-22
# Time:                        21:54:42   Log-Likelihood:                -1235.6
# No. Observations:                 168   AIC:                             2475.
# Df Residuals:                     166   BIC:                             2481.
# Df Model:                           1
# ...
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept        611.3125     31.719     19.273      0.000       548.689   673.936
# C(tau_)[T.1.0]   955.1458     83.920     11.382      0.000       789.459  1120.833
# ...

# %%
name = ['Lagrange multiplier statistic', 'p-value', 
        'f-value', 'f p-value']

from statsmodels.stats.diagnostic import het_breushpagan
test = het_breushpagan(max_full_ols.resid,max_full_ols.model.exog  )

zip(name, test)
# Out:
# [('Lagrange multiplier statistic', 0.065150305012947385),
#  ('p-value', 0.79853343053636527),
#  ('f-value', 0.064399680303355689),
#  ('f p-value', 0.79998658267293876)]

# %%
shapiro(max_full_ols.resid)
# Out:
# (0.8333949446678162, 1.4484371818265784e-12)

# %% [markdown]
# The outlier at $t$ = 20, September 2001, is infulenceing the model heavly as evidenced by the large Cook's d, student residual, dffits and dfbetas.

# %% [markdown]
# We will also create a to see the affect of removing the observation at $t$= 20

# %%
data_full_ols = data_df
data_df = pd.read_csv('data/txtdata_y2k.csv')
data_df = np.round(data_df, 0)
data_df = data_df[data_df.t != 20 ]

# %%
rsq_dict = {'rsq': []}
from statsmodels.formula.api import ols
for i in range(0, n_count_data):
    temp_model = ols_helper(i, data_df)
    rsq_dict['rsq'].append(temp_model.rsquared)
    
rsq_df = pd.DataFrame(rsq_dict)
data_df = pd.concat([data_df, rsq_df], axis = 1) 
chart_df = pd.DataFrame({'With Outlier': list(data_full_ols.rsq), 'No Outlier': list(data_df.rsq),})
chart_df.plot()
max_rsq = data_df[data_df.rsq == float(data_df.rsq.values.max())]
tau_full_ols = max_rsq.t
max_rsq
# Out:
#      iyear  imonth  nkill    t       rsq
# 145   2012       2   1039  145  0.527775

# %% [markdown]
# Without the outlier the switchpoint dummy $\tau_*$ has moved to 145. The the model less influenced has a higher $R^2$ and below you can notice the AIC has also decreased under this model.

# %%
max_full_ols = ols_helper(float(tau_full_ols), data_df)
test = het_breushpagan(max_full_ols.resid,max_full_ols.model.exog  )
zip(name, test)
# Out:
# [('Lagrange multiplier statistic', 5.5068176035423333),
#  ('p-value', 0.018942483133194212),
#  ('f-value', 5.6263979141475815),
#  ('f p-value', 0.018844343772470174)]

# %%
max_full_ols = ols_helper(float(tau_full_ols), data_df)
infl = max_full_ols.get_influence()
print max_full_ols.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  nkill   R-squared:                       0.512
# Model:                            OLS   Adj. R-squared:                  0.509
# Method:                 Least Squares   F-statistic:                     172.8
# Date:                Sun, 19 Apr 2015   Prob (F-statistic):           1.84e-27
# Time:                        10:42:06   Log-Likelihood:                -1202.2
# No. Observations:                 167   AIC:                             2408.
# Df Residuals:                     165   BIC:                             2415.
# Df Model:                           1
# ...
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept        599.5694     27.146     22.087      0.000       545.970   653.168
# C(tau_)[T.1.0]   961.5610     73.149     13.145      0.000       817.133  1105.989
# ...

# %% [markdown]
# ### A Bayesian Model for finding the switchpint

# %% [markdown]
# We want to answer the question between the years 2000 and 2013 has there been a change in the behavior of terroist around the world. Because we are dealing woth count data the perfect distribution to model this is the possion distribution, so the count in the $i$'s month will be represented by $y_i$,
#
# $$ y_i \sim \text{Poisson}(\lambda)  $$

# %% [markdown]
# We are looking for a time $t$ in the time series when the $\lambda$ (the behavior of terrorists) changes, we will call this $\tau$.
# In Bayesian literature $\tau$ whats known as a **switchpoint**. Later, we will comapre the two lambda model to the single labmda model.

# %% [markdown]
# $$
# \lambda =
# \begin{cases}
# \lambda_1  & \text{if } t \lt \tau \cr
# \lambda_2 & \text{if } t \ge \tau
# \end{cases}
# $$

# %% [markdown]
# Make inference on $\lambda$ we need to assign prior probabilities to $\lambda$, the simplest distribution to assign is a single perameter distribution. Because $\lambda$ can be any positive number the exponential distribution will be used. The exponential distribution takes it's own perameter, a hyper-paramerter, we will call them $\alpha$ and $\beta$. We will have make an inital guess on it's value this, however; should not influence our model too much. Using the expected value of exponential distribution we can get the expected value of the $\alpha$ and $\beta$.

# %% [markdown]
# $$\frac{1}{N}\sum_{i=0}^N \;C_i \approx E[\; \lambda_1 \; |\; \alpha ] = \frac{1}{\alpha}$$
#
# $$\frac{1}{N}\sum_{i=0}^N \;C_i \approx E[\; \lambda_2 \; |\; \beta ] = \frac{1}{\beta}$$

# %% [markdown]
# Before seeing the data there was no prior beleif about where the switchpint might lie so we model $\tau$ with a uniform prior distribution from the $t$=1 (Janurary 2000) to $t$=168 (December 2013).

# %% [markdown]
# \begin{align}
# & \tau \sim \text{DiscreteUniform(0,168) }\\\\
# & \Rightarrow P( \tau = k ) = \frac{1}{168}
# \end{align}

# %% [markdown]
# So, finally our full model looks like this...

# %% [markdown]
# $$\begin{array}{ccc}
# (y_t | \tau, \lambda_1, \lambda_2) \sim\text{Poisson}\left(\lambda\right), & \lambda=\left\{
# \begin{array}{lll}
# \lambda_1 &\text{if}& t< \tau\\
# \lambda_2 &\text{if}& t\ge \tau
# \end{array}\right.,&t\in[0,168]\\
# \tau \sim \text{DiscreteUniform}(0, 168)\\
# \lambda_1\sim \text{Gamma}(\alpha, \beta)\\
# \lambda_2\sim \text{Gamma}(\alpha, \beta)
# \end{array}$$

# %% [markdown]
# We need to find the marginal posterior distribution, to this we will use simulation to draw samples from the joint posterior distribution.

# %%
count_data = np.loadtxt("data/txtdata.csv")
count_data = np.round(count_data, 0)
# Custom Metropolis starting parameter to help with low accetptanve problem
class TruncatedMetropolis(pm.DiscreteMetropolis):
    def __init__(self, stochastic, low_bound, up_bound, *args, **kwargs):
        self.low_bound = low_bound
        self.up_bound = up_bound
        pm.DiscreteMetropolis.__init__(self, stochastic, *args, **kwargs)

    def propose(self):
        tau = 1./(self.adaptive_scale_factor * self.proposal_sd)**2
        self.stochastic.value = \
        pm.rtruncnorm(self.stochastic.value, tau, self.low_bound, self.up_bound)

    def hastings_factor(self):
        tau = 1./(self.adaptive_scale_factor * self.proposal_sd)**2
        cur_val = self.stochastic.value
        last_val = self.stochastic.last_value

        lp_for = pymc.truncnorm_like(cur_val, last_val, tau, self.low_bound, self.up_bound)
        lp_bak = pymc.truncnorm_like(last_val, cur_val, tau, self.low_bound, self.up_bound)

        if self.verbose > 1:
            print self._id + ': Hastings factor %f'%(lp_bak - lp_for)
        return lp_bak - lp_for

alpha = 1.0 / count_data.mean() 
beta = 1.0 / count_data.mean()
lambda_1 = pm.Gamma("lambda_1",1, alpha)
lambda_2 = pm.Gamma("lambda_2",1, beta)

tau = pm.DiscreteUniform( "tau", lower=0, upper=len(count_data))
@pm.deterministic
def lambda_(tau=tau, lambda_1=lambda_1, lambda_2=lambda_2):
    out = np.zeros(n_count_data)
    out[:tau] = lambda_1  
    out[tau:] = lambda_2 
    return out



observation = pm.Poisson("obs", lambda_, value=count_data, observed=True)
model = pm.Model([observation, lambda_1, lambda_2, tau])

from pymc import DiscreteMetropolis
mcmc = pm.MCMC(model)

mcmc.use_step_method(pm.AdaptiveMetropolis, [lambda_1, lambda_2])
mcmc.use_step_method(TruncatedMetropolis, tau ,0, len(count_data))
mcmc.sample(2000000, 200000,10)
# Making simulations for later use
sim = pm.Poisson("sim_model_1", lambda_)
sim_m1 = pm.MCMC([sim,observation, lambda_1, lambda_2, tau ])
N = 10000
sim_m1.sample(N)
# Out:
#  [                  0%                  ] 704 of 2200000 complete in 0.5 sec
#  [                  0%                  ] 1418 of 2200000 complete in 1.0 sec
#  [                  0%                  ] 2133 of 2200000 complete in 1.5 sec
#  [                  0%                  ] 2848 of 2200000 complete in 2.0 sec
#  [                  0%                  ] 3559 of 2200000 complete in 2.5 sec
#  [                  0%                  ] 4274 of 2200000 complete in 3.0 sec
#  [                  0%                  ] 4986 of 2200000 complete in 3.5 sec
#  [                  0%                  ] 5701 of 2200000 complete in 4.0 sec
#  [                  0%                  ] 6410 of 2200000 complete in 4.5 sec
#  [                  0%                  ] 7125 of 2200000 complete in 5.0 sec
#  [                  0%                  ] 7838 of 2200000 complete in 5.5 sec
#  [                  0%                  ] 8552 of 2200000 complete in 6.0 sec
# ...

# %%
uninfl_count = np.array(data_df.nkill.dropna())
alpha = 1.0 / uninfl_count.mean()  # Recall count_data is the
beta = 1.0 / uninfl_count.mean()
lambda_1 = pm.Gamma("lambda_1",1, alpha)
lambda_2 = pm.Gamma("lambda_2",1, beta)

tau = pm.DiscreteUniform( "tau", lower=0, upper=len(uninfl_count))
@pm.deterministic
def lambda_(tau=tau, lambda_1=lambda_1, lambda_2=lambda_2):
    out = np.zeros(len(uninfl_count))
    out[:tau] = lambda_1  # lambda before tau is lambda1
    out[tau:] = lambda_2  # lambda after (and including) tau is lambda2
    return out


observation = pm.Poisson("obs", lambda_, value=uninfl_count, observed=True)
model_uninfl = pm.Model([observation, lambda_1, lambda_2, tau])
from pymc import DiscreteMetropolis
uninfl_mcmc = pm.MCMC(model_uninfl)
uninfl_mcmc.use_step_method(pm.AdaptiveMetropolis, [lambda_1, lambda_2])
uninfl_mcmc.use_step_method(TruncatedMetropolis, tau ,0, len(uninfl_count))
uninfl_mcmc.sample(2000000, 200000,10)


sim = pm.Poisson("sim_model_2", lambda_)
sim_m2 = pm.MCMC([sim,observation, lambda_1, lambda_2, tau ])
N = 10000
sim_m2.sample(N)
# Out:
#  [                  0%                  ] 699 of 2000000 complete in 0.5 sec
#  [                  0%                  ] 1407 of 2000000 complete in 1.0 sec
#  [                  0%                  ] 2108 of 2000000 complete in 1.5 sec
#  [                  0%                  ] 2814 of 2000000 complete in 2.0 sec
#  [                  0%                  ] 3526 of 2000000 complete in 2.5 sec
#  [                  0%                  ] 4233 of 2000000 complete in 3.0 sec
#  [                  0%                  ] 4912 of 2000000 complete in 3.5 sec
#  [                  0%                  ] 5513 of 2000000 complete in 4.0 sec
#  [                  0%                  ] 6207 of 2000000 complete in 4.5 sec
#  [                  0%                  ] 6866 of 2000000 complete in 5.0 sec
#  [                  0%                  ] 7540 of 2000000 complete in 5.5 sec
#  [                  0%                  ] 8186 of 2000000 complete in 6.0 sec
# ...

# %% [markdown]
# ###Collecting Samples

# %%
lambda_1_samples = mcmc.trace('lambda_1')[:]
lambda_2_samples = mcmc.trace('lambda_2')[:]
tau_samples = mcmc.trace('tau')[:]

uninfl_lambda_1_samples = uninfl_mcmc.trace('lambda_1')[:]
uninfl_lambda_2_samples = uninfl_mcmc.trace('lambda_2')[:]
uninfl_tau_samples = uninfl_mcmc.trace('tau')[:]

# %%
dat = mcmc.
dat

# %%
mcmc.summary()
# Out:
# lambda_2:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	[[ 1566.38]]     [[ 8.041]]       [[ 0.03]]  [ 1550.452  1582.073]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	[[ 1550.582]]    [[ 1560.96]]    [[ 1566.351]]  [[ 1571.814]] [[ 1582.24]]
#
#
# lambda_1:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	[[ 611.31]]      [[ 2.066]]       [[ 0.009]]   [ 607.326  615.371]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	[[ 607.297]]     [[ 609.913]]    [[ 611.311]]   [[ 612.711]]  [[ 615.347]]
#
#
# tau:
#
# ...

# %%
(uninfl_mcmc.summary())
# Out:
# lambda_1:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	[[ 408.446]]     [[ 2.322]]       [[ 0.147]]   [ 404.402  412.813]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	[[ 404.402]]     [[ 406.908]]    [[ 408.376]]   [[ 410.479]]  [[ 412.813]]
#
#
# tau:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	[[ 72.]]         [[ 0.]]          [[ 0.]]              [ 72.  72.]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	[[ 72.]]         [[ 72.]]        [[ 72.]]       [[ 72.]]      [[ 72.]]
#
#
# lambda_2:
#
# ...

# %% [markdown]
# ###Checking Convergence and Autocorrelation

# %% [markdown]
# Geweke scores are calulated by,
#
# $$z = \frac{\bar{\theta}_a - \bar{\theta}_b}{\sqrt{Var(\theta_a) + Var(\theta_b)}}$$
# where \(a\) is the early interval and \(b\) the late interval.
# If the z-scores (theoretically distributed as standard normal variates) of these two segments are similar, it can provide evidence for convergence. The z-scores are calculated using the difference between various initial segments along the chain, and the last 50% of the remaining chain. If the chain has converged, the majority of points should fall within 2 standard deviations of zero.

# %%
figsize(19.5, 5)
# # Calculate and plot Geweke scores
trace = lambda_1_samples
alpha_scores = pm.geweke(trace, intervals=20)
pm.Matplot.geweke_plot(alpha_scores, '$\lambda_1$')

trace = lambda_2_samples
alpha_scores = pm.geweke(trace, intervals=20)
pm.Matplot.geweke_plot(alpha_scores, '$\lambda_2$')

pymc.Matplot.autocorrelation(mcmc)
# Out:
# Plotting lambda_2
# Cannot plot autocorrelation for lambda_2
# Plotting lambda_1
# Cannot plot autocorrelation for lambda_1
# Plotting tau

# %%
figsize(19.5, 5)
# # Calculate and plot Geweke scores
trace = uninfl_lambda_1_samples
alpha_scores = pm.geweke(trace, intervals=20)
pm.Matplot.geweke_plot(alpha_scores, '$\lambda_1$')

trace = uninfl_lambda_2_samples
alpha_scores = pm.geweke(trace, intervals=20)
pm.Matplot.geweke_plot(alpha_scores, '$\lambda_2$')

pymc.Matplot.autocorrelation(uninfl_mcmc)
# Out:
# Plotting lambda_1
# Plotting
#  tau
# Plotting
#  lambda_2

# %%
figsize(12.5, 10)
# histogram of the samples:

ax = plt.subplot(211)
# ax.set_autoscaley_on(False)

plt.hist(lambda_1_samples, bins=30, alpha=0.85,
         label="posterior of $\lambda_1$", color='#6baed6', normed=True)
plt.legend(loc="upper left")
plt.title(r"""Posterior distributions of the variables
    $\lambda_1,\;\lambda_2$""")
# plt.xlim([400, 500])
plt.xlabel("$\lambda_1$ value")

ax = plt.subplot(212)
# ax.set_autoscaley_on(False)
plt.hist(lambda_2_samples, bins=30, alpha=0.85,
         label="posterior of $\lambda_2$", color="#2171b5", normed=True)
plt.legend(loc="upper left")
# plt.xlim([15, 30])
plt.xlabel("$\lambda_2$ value")

# plt.subplot(313)
# w = 1.0 / tau_samples.shape[0] * np.ones_like(tau_samples)
# plt.hist(tau_samples, bins=n_count_data, alpha=1,
#          label=r"posterior of $\tau$",
#          color="#467821", weights=w, rwidth=2.)
# plt.xticks(np.arange(n_count_data))

# plt.legend(loc="upper left")
# # plt.ylim([0, .75])
# plt.xlim([140, 150])
# plt.xlabel(r"$\tau$ (in days)")
# plt.ylabel("probability");

# %%
figsize(12.5, 10)
# histogram of the samples:

ax = plt.subplot(211)
# ax.set_autoscaley_on(False)

plt.hist(uninfl_lambda_1_samples, bins=30, alpha=0.85,
         label="posterior of $\lambda_1$", color='#6baed6', normed=True)
plt.legend(loc="upper left")
plt.title(r"""Posterior distributions of the variables
    $\lambda_1,\;\lambda_2$""")
# plt.xlim([15, 30])
plt.xlabel("$\lambda_1$ value")

ax = plt.subplot(212)
# ax.set_autoscaley_on(False)
plt.hist(uninfl_lambda_2_samples, bins=30, alpha=0.85,
         label="posterior of $\lambda_2$", color="#2171b5", normed=True)
plt.legend(loc="upper left")
# plt.xlim([15, 30])
plt.xlabel("$\lambda_2$ value")

# plt.subplot(313)
# w = 1.0 / uninfl_tau_samples.shape[0] * np.ones_like(uninfl_tau_samples)
# plt.hist(uninfl_tau_samples, bins=len(uninfl_count), alpha=1,
#          label=r"posterior of $\tau$",
#          color="#467821", weights=w, rwidth=2.)
# plt.xticks(np.arange(len(uninfl_count)))

# plt.legend(loc="upper left")
# # plt.ylim([0, .75])
# plt.xlim([62, 82])
# plt.xlabel(r"$\tau$ (in days)")
# plt.ylabel("probability");

# %% [markdown]
# lambda_1:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	[[ 463.943]]     [[ 2.421]]       [[ 0.047]]   [ 459.209  468.635]
#
#
# lambda_2:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	[[ 993.303]]     [[ 1.383]]       [[ 0.1]]     [ 990.213  995.749]

# %% [markdown]
# ## Simulating Data

# %% [markdown]
# Below we estimate the posterior for a single lamdbda model.

# %% [markdown]
# ## Model Selection

# %% [markdown]
# Now we calculate the Bayes factor, the Bayesian equavalent to the marginal likelihood test which will tell us which under which model the data is more likey.
#
# $$K = \frac{\Pr(D|M_1)}{\Pr(D|M_2)} =\frac{\int\Pr(\theta_1|M_1)\Pr(D|\theta_1,M_1)\,d\theta_1}{\int \Pr(\theta_2|M_2)\Pr(D|\theta_2,M_2)\,d\theta_2}$$
#
#
# A value of $K$ > 1 means that $M_1$ is more strongly supported by the data under consideration than $M_2$
#
# To calculate the Bayes factor we use the simulated data under the $M_1$ and $M_2$ respectivly and use Kernel density estimation to estimate the probability density function (PDF). Then use the PDF to find the probability of the observed dataset.

# %%
def rsq_(sim, obs,tau, lambda_1, lambda_2):
    sst = sum ((obs - obs.mean())**2)
    ssr = sum( (obs[:tau] - lambda_1)**2 ) + sum( (obs[tau:] - lambda_2)**2 )
    return (1- (ssr/sst))

def marginal_like(sim, obs,tau, lambda_1, lambda_2):
    pdf_full1 = stats.kde.gaussian_kde(sim[:tau])
    pdf_full2 = stats.kde.gaussian_kde(sim[tau:])
    return (sum(pdf_full1.evaluate(obs[:tau])) + sum(pdf_full2.evaluate(obs[tau:])) )

simulated_1 = sim_m1.trace("sim_model_1")[:]
simulated_2 = sim_m2.trace("sim_model_2")[:]
m1_likes = []
m2_likes = []

for i in range(0, len(simulated_1)):
    marge = marginal_like(simulated_1[i], count_data,  sim_m1.trace("tau")[:][i],  sim_m1.trace("lambda_1")[:][i],  sim_m1.trace("lambda_2")[:][i] )
    m1_likes.append(marge)

for i in range(0, len(simulated_2)):
    marge = marginal_like(simulated_2[i], count_data,  sim_m2.trace("tau")[:][i],  sim_m2.trace("lambda_1")[:][i],  sim_m2.trace("lambda_2")[:][i] )
    m2_likes.append(marge)

# The Bayes Factor is...
k = np.sum(m2_likes)/np.sum(m1_likes)

# %%
np.sum(m2_likes)/np.sum(m1_likes)
# Out:
# 1.3671616517298808

# %%
np.sum(m2_likes)/np.sum(m1_likes)
# Out:
# 1.4444189960315328

# %%
figsize(19.5, 5)
# tau_samples, lambda_1_samples, lambda_2_samples contain
# N samples from the corresponding posterior distribution
N = tau_samples.shape[0]
expected_monthly = np.zeros(n_count_data)
for month in range(0, n_count_data):
    # ix is a bool index of all tau samples corresponding to
    # the switchpoint occurring prior to value of ' month'
    ix =  month < tau_samples
    # Each posterior sample corresponds to a value for tau.
    # for each day, that value of tau indicates whether we're "before"
    # (in the lambda1 "regime") or
    #  "after" (in the lambda2 "regime") the switchpoint.
    # by taking the posterior sample of lambda1/2 accordingly, we can average
    # over all samples to get an expected value for lambda on that  month.
    # As explained, the "message count" random variable is Poisson distributed,
    # and therefore lambda (the poisson parameter) is the expected value of
    # "message count".
    expected_monthly[ month] = (lambda_1_samples[ix].sum()
                                   + lambda_2_samples[~ix].sum()) / N


plt.plot(range(n_count_data), expected_monthly, lw=4, color="#E24A33",
         label="expected death count")
plt.xlim(0, n_count_data)
plt.xlabel(" month")
plt.ylabel("number of people killed in terror attcks")
plt.title("Bayesian Expected number of deaths with Outlier")
# plt.ylim(0, 60)
plt.bar(np.arange(len(count_data)), count_data, color="#348ABD", alpha=0.65,
        label="observed deaths per month")

plt.legend(loc="upper left");

# %%
figsize(19.5, 5)

for month in range(0, n_count_data):
    expected_monthly[ month] = 408.446 if month <= 73 else 977.816

plt.plot(range(n_count_data), expected_monthly, lw=4, color="#E24A33",
         label="expected death count")
plt.xlim(0, n_count_data)
plt.xlabel(" month")
plt.ylabel("number of people killed in terror attcks")
plt.title("Bayesian Expected number of deaths without Outlier")
# plt.ylim(0, 60)
plt.bar(np.arange(len(count_data)), count_data, color="#348ABD", alpha=0.65,
        label="observed deaths per month")

plt.legend(loc="upper left");

# %%
for month in range(0, n_count_data):
    expected_monthly[ month] = 611.3125 if month <= 144 else (611.3125 + 955.1458)

plt.plot(range(n_count_data), expected_monthly, lw=4, color="#E24A33",
         label="expected death count")
plt.xlim(0, n_count_data)
plt.xlabel(" month")
plt.ylabel("number of people killed in terror attcks")
plt.title("OLS Expected number of deaths with Outlier")
# plt.ylim(0, 60)
plt.bar(np.arange(len(count_data)), count_data, color="#348ABD", alpha=0.65,
        label="observed deaths per month")

plt.legend(loc="upper left");

# %%
for month in range(0, n_count_data):
    expected_monthly[ month] = 599.5694 if month <= 145 else (599.5694 + 961.5610)

plt.plot(range(n_count_data), expected_monthly, lw=4, color="#E24A33",
         label="expected death count")
plt.xlim(0, n_count_data)
plt.xlabel(" month")
plt.ylabel("number of people killed in terror attcks")
plt.title("OLS Expected number of deaths without Outlier")
# plt.ylim(0, 60)
plt.bar(np.arange(len(count_data)), count_data, color="#348ABD", alpha=0.65,
        label="observed deaths per month")

plt.legend(loc="upper left");
